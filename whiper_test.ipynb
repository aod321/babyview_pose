# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "distil-whisper/distil-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=25,
    batch_size=16,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample, return_timestamps=True)


print(result["text"])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#  Mr. Quilter is the apostle of the middle classes, and we are glad to welcome his gospel. Nor is Mr. Quilter's manner less interesting than his matter. He tells us that at this festive season of the year, with Christmas and roast beef looming before us, similes drawn from eating and its results occur most readily to the mind. He has grave doubts whether Sir Frederick Leighton's work is really Greek after all, and can discover in it but little of Rocky Ithaca. Linnell's pictures are a sort of up-ards and Adam paintings, and Mason's exquisite idylls are as national as a jingo poem. Mr. Burkett Foster's landscapes smile at one much in the same way that Mr. Carcker used to flash his teeth, and Mr. John Collier gives his sitter a cheerful slap on the back before he says like a shampooer and a turkish bath next man

# %%
result["chunks"]
# Out:
# [{'timestamp': (0.0, 6.6),
#   'text': ' Mr. Quilter is the apostle of the middle classes, and we are glad to welcome his gospel.'},
#  {'timestamp': (6.6, 11.32),
#   'text': " Nor is Mr. Quilter's manner less interesting than his matter."},
#  {'timestamp': (11.32, 16.86),
#   'text': ' He tells us that at this festive season of the year, with Christmas and roast beef looming'},
#  {'timestamp': (16.86, 23.67),
#   'text': ' before us, similes drawn from eating and its results occur most readily to the mind.'},
#  {'timestamp': (23.67, 29.67),
#   'text': " He has grave doubts whether Sir Frederick Leighton's work is really Greek after all, and can"},
#  {'timestamp': (29.67, 39.77),
#   'text': " discover in it but little of Rocky Ithaca. Linnell's pictures are a sort of up-ards and Adam paintings, and Mason's exquisite"},
#  {'timestamp': (39.77, 44.75),
#   'text': ' idylls are as national as a jingo poem.'},
#  {'timestamp': (44.75, 50.37),
#   'text': " Mr. Burkett Foster's landscapes smile at one much in the same way that Mr. Carcker used"},
#  {'timestamp': (50.37, 62.46),
#   'text': ' to flash his teeth, and Mr. John Collier gives his sitter a cheerful slap on the back before he says like a shampooer and a turkish bath next man'}]

# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from datasets import load_dataset


device = "cuda:0" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32

model_id = "distil-whisper/distil-large-v3"

model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id, torch_dtype=torch_dtype, low_cpu_mem_usage=True, use_safetensors=True
)
model.to(device)

processor = AutoProcessor.from_pretrained(model_id)

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    max_new_tokens=128,
    chunk_length_s=25,
    batch_size=16,
    torch_dtype=torch_dtype,
    device=device,
)

dataset = load_dataset("distil-whisper/librispeech_long", "clean", split="validation")
sample = dataset[0]["audio"]

result = pipe(sample, return_timestamps=True)
print(result["text"])
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
#  Mr. Quilter is the apostle of the middle classes, and we are glad to welcome his gospel. Nor is Mr. Quilter's manner less interesting than his matter. He tells us that at this festive season of the year, with Christmas and roast beef looming before us, similes drawn from eating and its results occur most readily to the mind. He has grave doubts whether Sir Frederick Leighton's work is really Greek after all, and can discover in it but little of Rocky Ithaca. Linnell's pictures are a sort of up-ards and Adam paintings, and Mason's exquisite idylls are as national as a jingo poem. Mr. Burkett Foster's landscapes smile at one much in the same way that Mr. Carcker used to flash his teeth, and Mr. John Collier gives his sitter a cheerful slap on the back before he says like a shampooer and a turkish bath next man

# %%
result['chunks']
# Out:
# [{'timestamp': (0.0, 6.6),
#   'text': ' Mr. Quilter is the apostle of the middle classes, and we are glad to welcome his gospel.'},
#  {'timestamp': (6.6, 11.32),
#   'text': " Nor is Mr. Quilter's manner less interesting than his matter."},
#  {'timestamp': (11.32, 16.86),
#   'text': ' He tells us that at this festive season of the year, with Christmas and roast beef looming'},
#  {'timestamp': (16.86, 23.67),
#   'text': ' before us, similes drawn from eating and its results occur most readily to the mind.'},
#  {'timestamp': (23.67, 29.67),
#   'text': " He has grave doubts whether Sir Frederick Leighton's work is really Greek after all, and can"},
#  {'timestamp': (29.67, 39.77),
#   'text': " discover in it but little of Rocky Ithaca. Linnell's pictures are a sort of up-ards and Adam paintings, and Mason's exquisite"},
#  {'timestamp': (39.77, 44.75),
#   'text': ' idylls are as national as a jingo poem.'},
#  {'timestamp': (44.75, 50.37),
#   'text': " Mr. Burkett Foster's landscapes smile at one much in the same way that Mr. Carcker used"},
#  {'timestamp': (50.37, 62.46),
#   'text': ' to flash his teeth, and Mr. John Collier gives his sitter a cheerful slap on the back before he says like a shampooer and a turkish bath next man'}]

# %%
file_name = "/data/yinzi/babyview_20240507/audios/Babyview_Main/00220001_GX010011_03.11.2024-03.17.2024_03.06.2024-1:59pm.mp3"
result = pipe(file_name, return_timestamps=True)

# %%
result["chunks"]
# Out:
# [{'timestamp': (0.0, 1.9), 'text': " Okay, let's get right up to by three."},
#  {'timestamp': (2.24, 3.82), 'text': " So I think we've grown away."},
#  {'timestamp': (4.1, 6.32), 'text': ' This one is a bottle-up and up.'},
#  {'timestamp': (6.72, 6.88), 'text': ' Yeah.'},
#  {'timestamp': (8.08, 8.44), 'text': ' Yeah.'},
#  {'timestamp': (24.67, 25.67),
#   'text': ' Wow. that price. So. Oh, wow. Are you my Tristan love? Whoa.'},
#  {'timestamp': (25.67, 26.67), 'text': ' Whoa.'},
#  {'timestamp': (26.67, 27.67), 'text': ' Blue.'},
#  {'timestamp': (27.67, 38.33),
#   'text': ' Do you need a blue? Happy birthday! Oh!'},
#  {'timestamp': (38.33, 39.33), 'text': ' Oh!'},
#  {'timestamp': (39.33, 40.33), 'text': ' Oh!'},
#  {'timestamp': (40.33, 79.67), 'text': " Yeah! Get it. It's a ball..."},
#  {'timestamp': (79.67, 83.67), 'text': ' It happened today!'},
#  {'timestamp': (83.67, 84.67), 'text': ' Yeah, look at that.'},
#  {'timestamp': (84.67, 86.67), 'text': " Oh, it's a snowman!"},
#  {'timestamp': (86.67, 90.33),
#   'text': " It's a ball man! Who's the ball man?"},
#  {'timestamp': (90.33, 96.33),
#   'text': " I'm the ball man. Oh my gosh. Oh my gosh, we're ball manning."},
#  {'timestamp': (96.33, 105.0), 'text': ' Ah, no, oh, oh, oh, ooh. Whoa! Ooh!'},
#  {'timestamp': (105.0, 107.0), 'text': " There's..."},
#  {'timestamp': (107.0, 109.0), 'text': ' Pink!'},
#  {'timestamp': (109.0, 111.0), 'text': ' Oh!'},
#  {'timestamp': (111.0, 113.0), 'text': ' Mama!'},
#  {'timestamp': (113.0, 115.0), 'text': ' Yes?'},
#  {'timestamp': (115.0, 116.0), 'text': ' Ma'},
#  {'timestamp': (116.0, 117.0), 'text': ' Ah!'},
#  {'timestamp': (117.0, 121.67), 'text': ' Ah! Oh. Oh. Hi.'},
#  {'timestamp': (121.67, 134.67), 'text': ' This has got to be a gallop.'},
#  {'timestamp': (134.67, 135.67), 'text': ' Yeah.'},
#  {'timestamp': (135.67, 137.79), 'text': ' Are you galloping?'},
#  {'timestamp': (137.79, 139.09), 'text': ' Are you riding Ney-N-A?'},
#  {'timestamp': (140.77, 142.09), 'text': ' No.'},
#  {'timestamp': (146.09, 148.29), 'text': ' Oh, yeah.'},
#  {'timestamp': (148.29, 153.05),
#   'text': ' Are you gonna put some place mats on your pillow, your bean bag?'},
#  {'timestamp': (155.0, 158.0), 'text': ' Your beanbag chair? Woo-hoo!'},
#  {'timestamp': (158.0, 159.0), 'text': ' Oh!'},
#  {'timestamp': (159.0, 163.0), 'text': ' Yeah.'},
#  {'timestamp': (163.0, 165.0), 'text': ' Hey.'},
#  {'timestamp': (165.0, 166.0), 'text': ' This right.'},
#  {'timestamp': (166.0, 167.0), 'text': " I'm a..."},
#  {'timestamp': (167.0, 171.67), 'text': " I'm sorry. It's"},
#  {'timestamp': (171.67, 173.67), 'text': " I'm"},
#  {'timestamp': (173.67, 195.33),
#   'text': ' a bite at it and the goodness see.'},
#  {'timestamp': (199.33, 200.33), 'text': ' Mama.'},
#  {'timestamp': (205.0, 207.0), 'text': ' Are you popping?'},
#  {'timestamp': (210.0, 211.0), 'text': ' Mop, mop, mop. Mop, mop.'},
#  {'timestamp': (211.0, 230.23),
#   'text': ' Mop, mop. Okay, I figured out one that was broken for sure.'},
#  {'timestamp': (230.23, 236.67),
#   'text': " I think there's another one that's broken, but of course it's hard to tell until you like fully pop it out and try to use it."},
#  {'timestamp': (244.33, 255.0),
#   'text': ' Oh, mop, mop? tell until you like fully pop it out and try to use it oh mop mop oh sweep the chair sweep the chair okay sweep the chair sweep the chair sweep the chair Good. Yeah, me on. Yeah.'},
#  {'timestamp': (255.0, 256.0), 'text': ' You know'},
#  {'timestamp': (256.0, 257.0), 'text': " there's a bit of"},
#  {'timestamp': (257.0, 259.0), 'text': ' there.'},
#  {'timestamp': (259.0, 288.33),
#   'text': " Good job. Right here. I'm gonna go to Sweep, sweep, sweep."},
#  {'timestamp': (288.33, 290.33), 'text': ' No, my sweeper.'},
#  {'timestamp': (290.33, 292.33), 'text': ' No, my sweeper?'},
#  {'timestamp': (292.33, 296.33),
#   'text': " Yeah, you're letting Kettle know that one's yours."},
#  {'timestamp': (296.33, 301.33), 'text': ' No?'},
#  {'timestamp': (301.33, 305.0),
#   'text': " Oh, we can't be on the beanbag chair?"},
#  {'timestamp': (305.0, 306.0), 'text': ' Okay.'},
#  {'timestamp': (306.0, 307.0), 'text': ' Okay.'},
#  {'timestamp': (307.0, 308.0), 'text': ' Okay.'},
#  {'timestamp': (308.0, 311.0), 'text': ' And we back here.'},
#  {'timestamp': (311.0, 312.0), 'text': ' Hey, hey.'},
#  {'timestamp': (312.0, 316.0), 'text': ' Hey, Tristan.'},
#  {'timestamp': (316.0, 317.0), 'text': ' Hello?'},
#  {'timestamp': (317.0, 318.0), 'text': ' Hello?'},
#  {'timestamp': (318.0, 323.57), 'text': ' Daddy stuck behind the placemats.'},
#  {'timestamp': (323.57, 325.23), 'text': " What's going on?"},
#  {'timestamp': (325.23, 331.45),
#   'text': " Whoa, whoa, dad's not stuck behind the placements anymore."},
#  {'timestamp': (331.45, 332.85), 'text': ' Thank you.'},
#  {'timestamp': (332.85, 335.91), 'text': ' Oh, go back behind the placemats.'},
#  {'timestamp': (335.91, 345.81),
#   'text': " Whoa, oh my gosh. Oh my gosh. I'm stuck behind the placemats again. What do I do? What do I do? Oh. Oh."},
#  {'timestamp': (349.81, 357.0),
#   'text': " Glad I'm not stuck behind those anymore."},
#  {'timestamp': (359.0, 360.0),
#   'text': ' Are you stuck behind the placemats? Whoa!'},
#  {'timestamp': (360.0, 361.0), 'text': ' Got him!'},
#  {'timestamp': (361.0, 362.0), 'text': ' Ah!'},
#  {'timestamp': (362.0, 363.0), 'text': ' Whoa!'},
#  {'timestamp': (367.0, 371.67),
#   'text': " Oh, Dad, don't get stuck behind the place mat. I'll be scary."},
#  {'timestamp': (373.67, 376.67),
#   'text': ' Your faithful to doodle will not appreciate you being stuck there forever.'},
#  {'timestamp': (377.67, 378.67), 'text': ' Hello.'},
#  {'timestamp': (379.67, 380.67), 'text': ' Hello.'},
#  {'timestamp': (380.67, 382.67), 'text': ' Is that Tristan?'},
#  {'timestamp': (382.67, 383.67), 'text': ' The place mat helper?'},
#  {'timestamp': (383.67, 386.67), 'text': ' Oh, oh no.'},
#  {'timestamp': (386.67, 388.33), 'text': ' Oh, oh, oh, oh, oh,'},
#  {'timestamp': (388.33, 392.33),
#   'text': ' Dad is unstuck from the place, Matt.'},
#  {'timestamp': (392.33, 393.33), 'text': ' What?'},
#  {'timestamp': (393.33, 398.33),
#   'text': " You're just watching to make sure it's still in the right mode."},
#  {'timestamp': (398.33, 401.33),
#   'text': " Yeah, it should, it's 10 minutes after you said, though, it's 10 minutes."},
#  {'timestamp': (401.33, 402.33), 'text': ' Whoa, did you do flops?'},
#  {'timestamp': (402.33, 405.0),
#   'text': " Well, it's been 20 minutes, so we try to go 30. Whoa, did you do flops? It's been 20 minutes. Yeah."},
#  {'timestamp': (405.0, 406.0), 'text': ' So we try to go 30.'},
#  {'timestamp': (406.0, 407.0), 'text': ' Oh, Flopsy?'},
#  {'timestamp': (407.0, 409.0), 'text': ' Are you flipsy, flopsie, flopsie?'},
#  {'timestamp': (409.0, 412.0),
#   'text': ' It ended up in like time lapse mode a couple weeks ago.'},
#  {'timestamp': (412.0, 413.0), 'text': ' Oh.'},
#  {'timestamp': (413.0, 418.0),
#   'text': " It, when it's in video, it like, does one flash."},
#  {'timestamp': (418.0, 423.67), 'text': " It's that, yeah. It's that."},
#  {'timestamp': (423.67, 424.67), 'text': ' Oh, well.'},
#  {'timestamp': (424.67, 426.67),
#   'text': " So it's not recording our performance."},
#  {'timestamp': (426.67, 427.67), 'text': ' How much?'},
#  {'timestamp': (427.67, 431.67),
#   'text': ' Well, yeah, like it accidentally was in time off smoke.'},
#  {'timestamp': (431.67, 435.67),
#   'text': ' And so I had to change it back to video.'},
#  {'timestamp': (435.67, 436.67), 'text': ' Oh, okay.'},
#  {'timestamp': (436.67, 440.33),
#   'text': ' Oh, did you get a Oh, did you get a mommy phone?'},
#  {'timestamp': (440.33, 442.33), 'text': ' Oh, thank you.'},
#  {'timestamp': (442.33, 445.33),
#   'text': ' Oh, you popping out the handle for me too?'},
#  {'timestamp': (445.33, 447.33), 'text': ' Thank you, Tristan.'},
#  {'timestamp': (447.33, 449.33), 'text': ' Blue ball.'},
#  {'timestamp': (449.33, 450.33), 'text': ' Blue ball?'},
#  {'timestamp': (450.33, 451.33), 'text': ' Blue ball?'},
#  {'timestamp': (451.33, 456.0),
#   'text': ' Oh, Daddy, no. Look, this. Oh, gotta get Tristan out.'},
#  {'timestamp': (456.0, 458.0), 'text': ' Gotta get her out.'},
#  {'timestamp': (458.0, 460.0), 'text': ' We got her out.'},
#  {'timestamp': (460.0, 462.0), 'text': ' We got her out.'},
#  {'timestamp': (462.0, 464.0), 'text': " Oh, but no, Dad's stuck."},
#  {'timestamp': (464.0, 466.0),
#   'text': " Oh, Dad's stuck behind the placemats."},
#  {'timestamp': (466.0, 468.0), 'text': " What's this going on?"},
#  {'timestamp': (468.0, 469.0), 'text': ' What?'},
#  {'timestamp': (469.0, 470.0), 'text': ' What?'},
#  {'timestamp': (470.0, 493.33),
#   'text': " Wow! Daddy's free. Daddy's free. Oh, oh no, Prisman, stop behind the blacemax. Oh, what do we do? Oh, my gosh. Oh! Oh, what's going to be in the placements?"},
#  {'timestamp': (493.33, 495.33), 'text': ' Oh no.'},
#  {'timestamp': (495.33, 497.33), 'text': ' Oh, my gosh!'},
#  {'timestamp': (497.33, 499.33),
#   'text': ' Daddy just stuck behind the placements.'},
#  {'timestamp': (499.33, 500.33), 'text': ' What happened?'},
#  {'timestamp': (500.33, 502.33), 'text': " Oh, what's going to happen?"},
#  {'timestamp': (502.33, 523.67),
#   'text': " Oh, I'm so scared. Oh, thank you, Tristan, for helping me with the placemats. Ah! Ha! Moma can."},
#  {'timestamp': (523.67, 526.67), 'text': ' My mama can.'},
#  {'timestamp': (526.67, 528.67), 'text': ' My mama turn.'},
#  {'timestamp': (528.67, 530.67), 'text': ' My mama turn.'},
#  {'timestamp': (530.67, 531.67), 'text': ' Oh.'},
#  {'timestamp': (531.67, 534.67), 'text': ' What happened?'},
#  {'timestamp': (534.67, 536.67), 'text': ' And where a truce would go?'},
#  {'timestamp': (536.67, 538.33), 'text': ' Oh, thank you!'},
#  {'timestamp': (538.33, 540.33), 'text': ' I thought that turn.'},
#  {'timestamp': (540.33, 541.33), 'text': ' Daddust turn?'},
#  {'timestamp': (541.33, 544.33),
#   'text': " All right, babe, I'm putting the nuts from our table right up here."},
#  {'timestamp': (544.33, 546.33), 'text': ' Mine.'},
#  {'timestamp': (546.33, 548.33), 'text': " Oh, you're gonna mop?"},
#  {'timestamp': (548.33, 549.33), 'text': " Well, Daddy's gonna roll."},
#  {'timestamp': (549.33, 552.33), 'text': ' Oh, Tristan roll?'},
#  {'timestamp': (552.33, 554.58), 'text': ' Oh, Tristan roll?'},
#  {'timestamp': (554.58, 556.32), 'text': " Oh, Tristan's foam roll?"},
#  {'timestamp': (557.04, 557.32), 'text': ' Okay.'},
#  {'timestamp': (557.6, 558.6), 'text': ' Not that there.'},
#  {'timestamp': (559.08, 560.06), 'text': " Tristan's foam rolling?"},
#  {'timestamp': (560.2, 560.42), 'text': ' Okay.'},
#  {'timestamp': (560.82, 561.5), 'text': ' You foam roll.'},
#  {'timestamp': (561.88, 562.62), 'text': ' Oh, wow.'},
#  {'timestamp': (562.78, 563.92), 'text': ' Look at you foam rolling.'},
#  {'timestamp': (565.76, 566.5), 'text': ' Oh, wow.'},
#  {'timestamp': (568.62, 569.12), 'text': ' Purple.'},
#  {'timestamp': (570.62, 571.67),
#   'text': ' Purple. Purple. Purple. Purple. Purple. Purple Toney. Purple, purple, purple, purple, purple,'},
#  {'timestamp': (571.67, 574.67), 'text': ' Papa, Papa, Papa, Penny.'},
#  {'timestamp': (574.67, 575.67), 'text': ' Penny.'},
#  {'timestamp': (575.67, 577.67), 'text': ' Purple Tony, please.'},
#  {'timestamp': (577.67, 578.67), 'text': ' Please.'},
#  {'timestamp': (578.67, 590.33),
#   'text': ' Oh, are you gonna play the puzzle instead? Whoa! Whoa!'},
#  {'timestamp': (590.33, 593.33), 'text': ' Whoa!'},
#  {'timestamp': (593.33, 597.33),
#   'text': ' Are you playing with some awesome color rings?'},
#  {'timestamp': (597.33, 598.33), 'text': ' Yeah.'},
#  {'timestamp': (598.33, 600.33), 'text': ' Totally awesome, dude.'},
#  {'timestamp': (600.33, 602.33), 'text': ' Oh, you get a phone roll?'},
#  {'timestamp': (602.33, 607.0),
#   'text': ' You need this. Okay. okay, you need this.'},
#  {'timestamp': (607.0, 608.0), 'text': ' Yeah.'},
#  {'timestamp': (608.0, 609.0), 'text': ' Oh no, Dadda.'},
#  {'timestamp': (609.0, 611.0), 'text': ' Okay, sorry, let me move my hand.'},
#  {'timestamp': (611.0, 613.0), 'text': " Didn't realize this is in your way."},
#  {'timestamp': (613.0, 614.0), 'text': ' Whoa!'},
#  {'timestamp': (616.0, 619.0),
#   'text': ' Yeah, you got a foam roll after riding your bike.'},
#  {'timestamp': (619.0, 653.33),
#   'text': ' Everybody knows this. I get a phone roll after riding your bike. Do you want to have blown up? Oh'},
#  {'timestamp': (653.33, 659.0), 'text': ' Do you want that ball blown up?'},
#  {'timestamp': (659.0, 660.0), 'text': ' Yeah.'},
#  {'timestamp': (662.0, 665.0), 'text': ' Okay, let, let daddy up.'},
#  {'timestamp': (665.0, 667.0),
#   'text': ' Let me make sure he slows his arthritis.'},
#  {'timestamp': (667.0, 669.0), 'text': ' Mama.'},
#  {'timestamp': (669.0, 672.67), 'text': " Mama. What's that, honey? Mama!"},
#  {'timestamp': (674.67, 691.33),
#   'text': " Where's that, Penny? Where's that, Penny? I'm Ackh"},
#  {'timestamp': (691.33, 692.33), 'text': ' Ack!'},
#  {'timestamp': (692.33, 693.33), 'text': ' A'},
#  {'timestamp': (693.33, 694.33), 'text': ' A'},
#  {'timestamp': (694.33, 695.33), 'text': ' A'},
#  {'timestamp': (695.33, 696.33), 'text': ' A'},
#  {'timestamp': (696.33, 697.33), 'text': ' A'},
#  {'timestamp': (697.33, 715.0), 'text': ' So Oh yeah?'},
#  {'timestamp': (715.0, 716.0), 'text': ' Oh yeah?'},
#  {'timestamp': (716.0, 723.66), 'text': ' Mom. Mom!'},
#  {'timestamp': (725.66, 726.66), 'text': " What's up?"},
#  {'timestamp': (730.66, 733.66), 'text': ' Mommy is high and Brubal.'},
#  {'timestamp': (733.66, 735.66), 'text': ' Bribal.'},
#  {'timestamp': (735.66, 738.33), 'text': ' Mommy brouba. Mommy, Bupa.'},
#  {'timestamp': (738.33, 740.33), 'text': ' Mommy, Bupa.'},
#  {'timestamp': (740.33, 742.33), 'text': ' Mommy throw it?'},
#  {'timestamp': (742.33, 744.33), 'text': ' Manny hot.'},
#  {'timestamp': (744.33, 745.33), 'text': ' Dupa.'},
#  {'timestamp': (745.33, 746.33), 'text': ' Okay.'},
#  {'timestamp': (746.33, 749.33), 'text': ' Bucal.'},
#  {'timestamp': (749.33, 751.33), 'text': ' Okay.'},
#  {'timestamp': (751.33, 753.33), 'text': ' Bipo.'},
#  {'timestamp': (753.33, 756.0), 'text': ' Bail. Hmm. This is an...'},
#  {'timestamp': (756.0, 759.0), 'text': ' Oh, look.'},
#  {'timestamp': (759.0, 761.0), 'text': ' Yeah.'},
#  {'timestamp': (761.0, 762.0), 'text': ' Yeah.'},
#  {'timestamp': (762.0, 771.66),
#   'text': ' Whoa. Whoa! Whoa! Ha ha ha ha! Yeah!'},
#  {'timestamp': (771.66, 772.66), 'text': ' Do you little goose?'},
#  {'timestamp': (772.66, 774.66), 'text': ' You chute?'},
#  {'timestamp': (774.66, 775.66), 'text': ' Yeah.'},
#  {'timestamp': (775.66, 778.66), 'text': ' Mommy,'},
#  {'timestamp': (778.66, 780.66), 'text': ' put blue ball.'},
#  {'timestamp': (780.66, 783.66), 'text': ' Mommy throw blue ball?'},
#  {'timestamp': (783.66, 784.66), 'text': ' Yeah.'},
#  {'timestamp': (784.66, 785.66), 'text': ' Yeah.'},
#  {'timestamp': (785.66, 788.33), 'text': ' I got the blue ball. A blue ball.'},
#  {'timestamp': (788.33, 789.33), 'text': ' A piece.'},
#  {'timestamp': (789.33, 806.0), 'text': ' A piece. A pink ball.'},
#  {'timestamp': (806.0, 809.0), 'text': ' A pink ball.'},
#  {'timestamp': (809.0, 811.0), 'text': ' A pink ball.'},
#  {'timestamp': (811.0, 812.0), 'text': ' A pink ball.'},
#  {'timestamp': (812.0, 815.0),
#   'text': ' Did Daddy get your new pink soccer ball?'},
#  {'timestamp': (815.0, 817.0), 'text': ' Yeah.'},
#  {'timestamp': (817.0, 819.0), 'text': ' Thank you, Daddy.'},
#  {'timestamp': (819.0, 821.66), 'text': ' Did you hear thank you daddy?'},
#  {'timestamp': (821.66, 823.66), 'text': " Oh, you're welcome, Tristan."},
#  {'timestamp': (823.66, 825.66), 'text': ' Daddy thinks these are what?'},
#  {'timestamp': (825.66, 826.66), 'text': ' Needle wire.'},
#  {'timestamp': (826.66, 831.66),
#   'text': " It's okay if things aren't perfectly"},
#  {'timestamp': (831.66, 832.82), 'text': " inflated when it's"}]
